# %%
import pandas as pd
import openpyxl

# %%
ls
# Out:
# Krylon 09-05-2024_saved 2.xlsx  installed_packages.txt
# README.md                       main1.py
# __pycache__/                    myprojectenv/
# chroma.log                      ollama_prompt.py
# data.xlsx                       path_to_your_database.db
# data_wrangling.ipynb            pdm.lock
# ecommerce.db                    pyproject.toml
# ecommerce1.db                   src/
# ecommerce_data.py               tests/

# %%
df = pd.read_excel('data.xlsx')

# %%
df1 = pd.read_excel('/Users/ghanshyam/Projects/fornax/llm/langchain/Krylon 09-05-2024_saved 2.xlsx', sheet_name='Analysis')

# %%
df1
# Out:
#            Unnamed: 0      Unnamed: 1  \
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 13167         WA37300      STB2-37300
# 13168          WD0002           01272
# 13169          WOO005             207
# 13170  YJTD-DB300-E-C  YJTD-DB300-E-C
# 13171       Z312STC15               0
#
#                                               Unnamed: 2 Unnamed: 3  \
# 0                                                    NaN        NaN
# 1                                                    NaN        NaN
# 2                                                    NaN        NaN
# 3                                                    NaN        NaN
# 4                                                    NaN        NaN
# ...                                                  ...        ...
# ...

# %%
df2 = pd.read_excel('/Users/ghanshyam/Projects/fornax/llm/langchain/Krylon 09-05-2024_saved 2.xlsx', sheet_name='Data')

# %%
df2
# Out:
#                  item  2022-06-01 00:00:00  2022-07-01 00:00:00  \
# 0              000000                 1550                 1086
# 1              000123                 2917                    0
# 2              010803                    0                    0
# 3              010804                  225                  536
# 4              100001                  632                   10
# ...               ...                  ...                  ...
# 13142         WA37300                    0                    0
# 13143          WD0002                    0                    0
# 13144          WOO005                    0                    0
# 13145  YJTD-DB300-E-C                12900                    0
# 13146       Z312STC15                    0                    0
#
#        2022-08-01 00:00:00  2022-09-01 00:00:00  2022-10-01 00:00:00  \
# 0                      931                 1272                 1085
# ...
